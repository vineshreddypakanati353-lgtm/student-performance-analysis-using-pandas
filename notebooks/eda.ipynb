# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import os
df = pd.read_csv('../data/raw/students_performance.csv')
# # df
# # print(df.head())
# # df.info()
# # df.describe()
# # df.isnull().sum()
# # corr = df.corr(numeric_only=True)
# # print(corr['GPA'].sort_values(ascending=False))
# # df.to_csv('../data/processed/clean_students.csv', index=False)
# # sns.scatterplot(x='Absences', y='GPA', data=df)
# # plt.title("Absences vs GPA")
# # sns.scatterplot(x='StudyTimeWeekly', y='GPA', data=df)
# # plt.title("Study Time vs GPA")
# # sns.boxplot(x='ParentalSupport', y='GPA', data=df)
# # sns.boxplot(x='Tutoring', y='GPA', data=df)
# # sns.histplot(df['GPA'], bins=20)
# # df['Passed'] = df['GPA'].apply(lambda x: 1 if x >= 2.0 else 0)
# # plt.show()
# # df['Passed'].value_counts()
# # df[['GPA', 'Absences', 'StudyTimeWeekly', 'ParentalSupport', 'Tutoring']].corr()
# # df[['GPA','Absences']].corr()
# # df.groupby('Tutoring')['GPA'].mean()
# # df.groupby('ParentalSupport')['GPA'].mean()
# df.groupby(['Tutoring','ParentalSupport'])['GPA'].mean()
# df.head()
# df['StudyTimeWeekly'].max()
# Out:
# Tutoring  ParentalSupport
# 0         0                  1.492119
#           1                  1.676359
#           2                  1.778492
#           3                  1.957196
#           4                  2.104226
# 1         0                  1.658971
#           1                  1.933297
#           2                  2.124766
#           3                  2.245512
#           4                  2.392266
# Name: GPA, dtype: float64
